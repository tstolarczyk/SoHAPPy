# %% [markdown]
# # Single source analysis
# Use a saved simulation - could used a saved Datasets when bug will be solved

# %%
import gammapy
if (gammapy.__version__ != "0.17"):
    print("Not sure it will work, use Gammapy 0.17 !")

# %%
import sys
sys.path.append("../") 
from pathlib import Path
import numpy as np

import astropy.units as u
import matplotlib.pyplot as plt
# Bigger texts and labels
#plt.style.use('seaborn-talk')
plt.style.use('seaborn-poster') # Bug with normal x marker !!!

from dataset_tools import createonoff_from_simulation, check_datasets
import dataset_plot as dplt
# Transform warnings into errors - useful to find who is guilty !
import warnings
#warnings.filterwarnings('error')
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ef887e18b7f7> in <module>
#      10 plt.style.use('seaborn-poster') # Bug with normal x marker !!!
#      11
# ---> 12 from dataset_tools import createonoff_from_simulation, check_datasets
#      13 import dataset_plot as dplt
#      14 # Transform warnings into errors - useful to find who is guilty !
#
# ModuleNotFoundError: No module named 'dataset_tools'

# %% [markdown]
# # Read data

# %%
# Read data from a simulation on disk
folder = r"D:\000_Today\testnew"
#file = "Event3-North.bin" # 4 slices
#file = "Event3-South.bin" # 4 slices
file = "Event85-South.bin" # 4 slices
file = "Event815-North.bin" # 24 slices
file = "Event901-North.bin" # 24 slices
file = "Event398-North.bin" # 24 slices

import pickle
infile  = open(Path(folder,file),"rb")
mc      = pickle.load(infile)
infile.close()

# %% [markdown]
# ## Create on-off datasets

# %%
dset_list = createonoff_from_simulation(mc,debug=False,fake=True)

# %% [markdown]
# ### Dataset count numbers and flux values at center of bins

# %%
check_datasets(dset_list,deeper=True)
# Out:
# ==========================================================================================
#  0    North-0-0    332.49 s     303.00     253.60      49.40      59.81   Spec-31
# ==========================================================================================
#     34.6  [   30.0,    40.0]       0.00       0.00       0.00       0.00    0     1.21e-10
#     47.4  [   40.0,    56.2]       0.00       0.00       0.00       0.00    0     5.55e-11
#     78.6  [   56.2,   110.0]      41.00      12.00      29.00      27.33    0     1.08e-11
#    139.9  [  110.0,   177.8]     175.00     159.40      15.60      29.26    1     4.81e-13
#    237.1  [  177.8,   316.2]      59.00      59.00       0.00       3.12    1     3.47e-15
#    421.7  [  316.2,   562.3]      18.00      16.80       1.20       0.09    1     2.21e-18
#    749.9  [  562.3,  1000.0]       8.00       5.20       2.80       0.00    1     1.35e-21
#   1333.5  [ 1000.0,  1778.3]       0.00       0.60      -0.60       0.00    1     3.74e-25
#   2371.4  [ 1778.3,  3162.3]       1.00       0.40       0.60       0.00    1     5.37e-31
#   4217.0  [ 3162.3,  5623.4]       1.00       0.20       0.80       0.00    1     1.96e-51
#   7498.9  [ 5623.4, 10000.0]       0.00       0.00       0.00       0.00    1     0.00e+00
#  12247.4  [10000.0, 15000.0]       0.00       0.00       0.00       0.00    0     0.00e+00
# ==========================================================================================
#  1    North-1-0    710.00 s     278.00     212.20      65.80      71.95   Spec-32
# ==========================================================================================
#     34.6  [   30.0,    40.0]       0.00       0.00       0.00       0.00    0     9.00e-11
#     47.4  [   40.0,    56.2]       0.00       0.00       0.00       0.00    0     4.12e-11
#     78.6  [   56.2,   110.0]      49.00      14.40      34.60      37.60    0     7.98e-12
#    139.9  [  110.0,   177.8]     171.00     137.00      34.00      31.33    1     3.56e-13
#    237.1  [  177.8,   316.2]      41.00      44.60      -3.60       2.91    1     2.57e-15
#    421.7  [  316.2,   562.3]      15.00      12.00       3.00       0.11    1     1.64e-18
#    749.9  [  562.3,  1000.0]       1.00       3.00      -2.00       0.00    1     1.00e-21
#   1333.5  [ 1000.0,  1778.3]       0.00       1.00      -1.00       0.00    1     2.79e-25
#   2371.4  [ 1778.3,  3162.3]       0.00       0.20      -0.20       0.00    1     4.03e-31
#   4217.0  [ 3162.3,  5623.4]       0.00       0.00       0.00       0.00    1     1.48e-51
#   7498.9  [ 5623.4, 10000.0]       0.00       0.00       0.00       0.00    1     0.00e+00
#  12247.4  [10000.0, 15000.0]
#    237.1  [  177.8,   316.2]     119.00     120.00      -1.00       2.28    1     7.36e-16
#    421.7  [  316.2,   562.3]      42.00      31.40      10.60       0.09    1     4.69e-19
#    749.9  [  562.3,  1000.0]      11.00      10.60       0.40       0.00    1     2.88e-22
#   1333.5  [ 1000.0,  1778.3]       3.00       2.40       0.60       0.00    1     8.10e-26
#   2371.4  [ 1778.3,  3162.3]       0.00       1.20      -1.20       0.00    1     1.17e-31
#   4217.0  [ 3162.3,  5623.4]       0.00       0.20      -0.20       0.00    1     4.35e-52
#   7498.9  [ 5623.4, 10000.0]       0.00       0.00       0.00       0.00    1     0.00e+00
#  12247.4  [10000.0, 15000.0]       0.00       0.00       0.00       0.00    0     0.00e+00

# %% [markdown]
# ## Plot excess/expected counts
# No error bars are plotted

# %%
dplt.panels(dset_list,dplt.excess_counts,fixrange=True,ysize=5,nmaxcol=4,xscale="log",yscale="log")
dplt.panels(dset_list,dplt.residuals,ysize=3,nmaxcol=4,yscale="linear")
# Out:
# >>>>>  [[[0.0000000e+00]]
#
#  [[0.0000000e+00]]
#
#  [[2.7333931e+01]]
#
#  [[2.9256458e+01]]
#
#  [[3.1242106e+00]]
#
#  [[9.2099875e-02]]
#
#  [[7.8189326e-04]]
#
#  [[4.1112517e-07]]
#
#  [[2.3317874e-11]]
#
#  [[1.3633961e-16]]
#
#  [[0.0000000e+00]]
#
#  [[0.0000000e+00]]]
# >>>>>  [[[0.0000000e+00]]
#
#  [[0.0000000e+00]]
#
#  [[3.7604805e+01]]
#
#  [[3.1326351e+01]]
#
#  [[2.9119387e+00]]
#
#  [[1.0972069e-01]]
#
#  [[1.1087628e-03]]
#
#  [[4.4276351e-07]]
#
#  [[3.4684835e-11]]
#
#  [[2.1452536e-16]]
#
#  [[0.0000000e+00]]
#
#  [[0.0000000e+00]]]
# >>>>>  [[[0.0000000e+00]]
#
#  [[0.0000000e+00]]
#
#  [[3.6085445e+01]]
#
#  [[3.0042179e+01]]
#
#  [[2.7898006e+00]]
#
#  [[1.0496125e-01]]
#
#  [[1.0600599e-03]]
#
#  [[4.2352787e-07]]
#
#  [[3.3377644e-11]]
#
#  [[2.0675342e-16]]
#
#  [[0.0000000e+00]]
#
#  [[0.0000000e+00]]]
# >>>>>  [[[0.00000000e+00]]
#
#  [[0.00000000e+00]]
#
#  [[3.48588791e+01]]
#
#  [[2.89905777e+01]]
#
#  [[2.68728161e+00]]
#
#  [[1.01011425e-01]]
#
#  [[1.01993571e-03]]
#
#  [[4.07529427e-07]]
#
#  [[3.22051726e-11]]
#
#  [[2.00294294e-16]]
#
#  [[0.00000000e+00]]
#
#  [[0.00000000e+00]]]
# >>>>>  [[[0.0000000e+00]]
#
#  [[0.0000000e+00]]
#
#  [[3.0505600e+01]]
#
#  [[2.5361044e+01]]
#
#  [[2.3497889e+00]]
#
#  [[8.8210493e-02]]
#
#  [[8.9012756e-04]]
#
#  [[3.5535260e-07]]
#
#  [[2.8080628e-11]]
#
#  [[1.7451892e-16]]
#
#  [[0.0000000e+00]]
#
#  [[0.0000000e+00]]]
# >>>>>  [[[0.0000000e+00]]
#
#  [[0.0000000e+00]]
#
#  [[2.9748566e+01]]
#
#  [[2.4703636e+01]]
#
#  [[2.2847569e+00]]
#
#  [[8.5682645e-02]]
#
#  [[8.6456188e-04]]
#
#  [[3.4589411e-07]]
#
#  [[2.7326306e-11]]
#
#  [[1.7035085e-16]]
#
#  [[0.0000000e+00]]
#
#  [[0.0000000e+00]]]

# %% [markdown]
# ## Extract the flux from the count numbers

# %%
dplt.panels(dset_list,nmaxcol=4, xsize=8, ysize=7, fixrange = True, func=dplt.extracted_spectrum,
           index=2,style="bar")

# %% [markdown]
# # Analysis datasets - time evolution

# %% [markdown]
# ### Excess counts

# %%
fig,ax = plt.subplots(figsize=(8,8))
dplt.excess_versus_time(dset_list, ax = ax, rate=False, unmasked=True, xscale="log", yscale="linear",debug=False)

# %% [markdown]
# ## Flux

# %%
# Plot the flux time evolution for a give range (limited to the reco axis range)
ax = dplt.flux_versus_time(dset_list, emin=10*u.GeV, emax=50000*u.GeV,
                     style="line",
                     color="tab:blue",debug=False)
ax.set_yscale("log")
ax.set_xscale("log")

# %%
# Plot the flux time evolution fr a series of energy ranges 
dplt.fluxes_versus_time(dset_list,nstep=2,debug=False,xscale="log")

# %% [markdown]
# ## Lightcurve simulation

# %%
ax = dplt.lightcurve(dset_list,tag="excess",style="line",binwidth=10*u.s,tmax=1000*u.s,xscale="log")
dplt.lightcurve(dset_list,tag="prediction",style="bar",color="tab:blue",alpha=0.2,ax=ax,binwidth=10*u.s,tmax=1000*u.s,xscale="log")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-7d65906875b6> in <module>
# ----> 1 ax = dplt.lightcurve(dset_list,tag="excess",style="line",binwidth=10*u.s,tmax=1000*u.s,xscale="log")
#       2 dplt.lightcurve(dset_list,tag="prediction",style="bar",color="tab:blue",alpha=0.2,ax=ax,binwidth=10*u.s,tmax=1000*u.s,xscale="log")
#
# TypeError: lightcurve() got an unexpected keyword argument 'xscale'

# %% [markdown]
# # <font color="red">CHECK THIS</font>

# %%
livetimes = np.asarray([ds.livetime.value for ds in dset_list]) # Measurement end of period
livetimes = np.append(np.asarray(0),livetimes) # Add zero to times
counts = np.asarray([ds.excess.data[ds.mask_safe].sum() for ds in dset_list]) # Measurement end of period
tmeas = []
tbin=[]
errt = []
t_elapsed = 0
for i,dt in enumerate(livetimes):
    tbin.append(t_elapsed + 0.5*dt)
    t_elapsed += dt
    errt.append(0.5*dt)
    tmeas.append(t_elapsed)

# %%
fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(10,5))
ax.errorbar(tbin[1:],counts,xerr=errt[1:],yerr=np.sqrt(counts),marker="+",ls="",color="black") # measurement points
ax.plot(tmeas[1:],counts,marker="o",color="red",ls="") # measurement points

# %% [markdown]
# # Check cumulated statistics
# Note that flux stacking is not possible form the dataset stacking methods

# %%
from dataset_tools import stacking
dset_stacked = stacking(dset_list)

# %% [markdown]
# ## Cumulated counts

# %%
check_datasets(dset_stacked,masked=False,deeper=True)

# %%
dplt.panels(dset_stacked,dplt.excess_counts,fixrange=True,ysize=7,nmaxcol=4,xscale="log",yscale="log",stacked=True)
# residuals have no sense here !

# %%
dplt.panels(dset_stacked,dplt.extracted_spectrum,
           fixrange=True,ysize=7,nmaxcol=4,xscale="log",yscale="log",theory=True)

# %% [markdown]
# ## Cumulated counts versus time

# %%
dplt.stacked_versus_time(dset_stacked,dsets=dset_list, rate=False,xscale="log",yscale="log")

# %% [markdown]
# # <font color="red">Check this</font>

# %%
# Counts versus time and energy
counts_versus_E_and_time(ds_stacked)

# %%
flux_unit="GeV-1 cm-2 s-1"
e_unit="GeV"
index = 2
x = 3*u.Unit("TeV-1 cm-2 s-1")*(1*u.TeV)**2
x

# %%
x.to(flux_unit*e_unit**2)
